# %% [markdown]
# # Bike_Details_Dataset_Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("BIKE DETAILS.csv")
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.1+ KB

# %%
df.shape
# Out:
# (1061, 7)

# %%
df.describe()
# Out:
#        selling_price         year      km_driven  ex_showroom_price
# count    1061.000000  1061.000000    1061.000000       6.260000e+02
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       7.749659e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %%
df.isnull().sum()  #detect missing values
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
df.count()
# Out:
# name                 1061
# selling_price        1061
# year                 1061
# seller_type          1061
# owner                1061
# km_driven            1061
# ex_showroom_price     626
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df = df.drop_duplicates()
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Handle missing value
df["ex_showroom_price"] = df["ex_showroom_price"].fillna(df["ex_showroom_price"].median())

# %%
df["ex_showroom_price"]
# Out:
# 0        72752.5
# 1        72752.5
# 2       148114.0
# 3        89643.0
# 4        72752.5
#           ...
# 1056     52000.0
# 1057     51000.0
# 1058     57000.0
# 1059     58000.0
# 1060     75000.0
# Name: ex_showroom_price, Length: 1055, dtype: float64

# %%
df["ex_showroom_price"].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# name                 0
# selling_price        0
# year                 0
# seller_type          0
# owner                0
# km_driven            0
# ex_showroom_price    0
# dtype: int64

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.seller_type.value_counts()
# Out:
# seller_type
# Individual    1049
# Dealer           6
# Name: count, dtype: int64

# %%
#Summary Statitstics
num_summary = df.describe()
cat_summary = df.select_dtypes(include=["object"]).nunique()

# %%
num_summary
# Out:
#        selling_price         year      km_driven  ex_showroom_price
# count    1055.000000  1055.000000    1055.000000       1.055000e+03
# mean    59713.818957  2013.871090   34295.628436       8.177786e+04
# std     56414.384170     4.305734   51708.286608       6.013443e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       6.458900e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       7.851300e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %%
cat_summary
# Out:
# name           279
# seller_type      2
# owner            4
# dtype: int64

# %%
#Outlier detection

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(y=df["selling_price"], color="lightblue")
plt.ylabel("Selling Price (₹)")
plt.title("Box Plot of Selling Prices")

# Boxplot for km_driven
plt.subplot(1, 2, 2)
sns.boxplot(y=df["km_driven"], color="lightcoral")
plt.ylabel("Kilometers Driven")
plt.title("Box Plot of Kilometers Driven")

plt.show()

# %%
#insights >> 
#Selling price >> There are some very high-priced bikes (outliers).
#Kilometers Driven >> Extreme outliers exist, with some bikes driven over 8,50,000 km.

# %%
#Feature Distribution

# Histograms for numerical features
df.hist(figsize=(12, 6), bins=30, color="skyblue", edgecolor="black")
plt.suptitle("Histograms of Numerical Features", fontsize=16)
plt.show()

# %%
#Categorical feature analysis
plt.figure(figsize=(12, 5))

# Seller Type Distribution
plt.subplot(1, 2, 1)
sns.countplot(x=df["seller_type"], palette="coolwarm")
plt.xlabel("Seller Type")
plt.ylabel("Count")
plt.title("Distribution of Seller Type")

# Owner Distribution
plt.subplot(1, 2, 2)
sns.countplot(x=df["owner"], palette="viridis", order=df["owner"].value_counts().index)
plt.xlabel("Owner Type")
plt.ylabel("Count")
plt.title("Distribution of Bike Ownership")

plt.show()

# %% [markdown]
# # Questions

# %%
#Q1> What is the range of selling prices in the dataset?

min_price = df["selling_price"].min()
max_price = df["selling_price"].max()
price_range = max_price - min_price

# %%
min_price, max_price, price_range
# Out:
# (5000, 760000, 755000)

# %%
#Ans>> The range of selling prices in the dataset is 755000.

# %%
#Q2> What is the median selling price for bikes in the dataset?

median_price = df["selling_price"].median()
median_price
# Out:
# 45000.0

# %%
#Ans>> The median selling price for bikes in the dataset is 45000.0

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
#Q3> What is the most common seller type?

df['seller_type'].mode()
# Out:
# 0    Individual
# Name: seller_type, dtype: object

# %%
df['seller_type'].mode()[0]
# Out:
# 'Individual'

# %%
#Ans>> The most common seller type is Individual

# %%
#Q4>> How many bikes have driven more than 50,000 kilometers?

df[df['km_driven'] > 50000]
# Out:
#                                name  selling_price  year seller_type  \
# 5                  Honda CB Twister          18000  2010  Individual
# 15    Suzuki Access 125 [2007-2016]          25000  2012  Individual
# 20             Hero Passion Pro 110          15000  2008  Individual
# 31          Yamaha FZ S [2012-2016]          38000  2013  Individual
# 43                Hero Passion XPro          28000  2012  Individual
# ...                             ...            ...   ...         ...
# 1049            Hero Super Splendor          20000  2007  Individual
# 1050               Bajaj Pulsar 150          20000  2010  Individual
# 1056                      Activa 3g          17000  2010  Individual
# 1059                 Honda CB Shine          12000  2009  Individual
# 1060               Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# 5     1st owner      60000            53857.0
# ...

# %%
df[df['km_driven'] > 50000].shape[0]
# Out:
# 168

# %%
#Ans>> 168 bikes have driven more than 50000 km.

# %%
#Q5>> What is the average km_driven value for each ownership type?

df.groupby('owner')['km_driven'].mean()
# Out:
# owner
# 1st owner     32732.710240
# 2nd owner     39288.991870
# 3rd owner     33292.181818
# 4th owner    311500.000000
# Name: km_driven, dtype: float64

# %%
#Q6>> What proportion of bikes are from the year 2015 or older?

(df[df["year"] <= 2015].shape[0])
# Out:
# 597

# %%
(df[df["year"] <= 2015].shape[0]) / df.shape[0]
# Out:
# 0.5658767772511848

# %%
#Q7>> What is the trend of missing values across the dataset?

df.isnull().sum()
# Out:
# name                 0
# selling_price        0
# year                 0
# seller_type          0
# owner                0
# km_driven            0
# ex_showroom_price    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
#Q8>> What is the highest ex_showroom_price recorded, and for which bike?

df['ex_showroom_price'].max()
# Out:
# 1278000.0

# %%
df.loc[df["ex_showroom_price"].idxmax(), "name"]
# Out:
# 'Harley-Davidson Street Bob'

# %%
#Ans>> ₹12,78,000 price for Harley-Davidson Street Bob

# %%
#Q9>> What is the total number of bikes listed by each seller type?

df["seller_type"].value_counts()
# Out:
# seller_type
# Individual    1049
# Dealer           6
# Name: count, dtype: int64

# %%
#Q10>> What is the relationship between selling_price and km_driven for first-owner bikes?

first_owner_bikes = df[df["owner"] == "1st owner"]
first_owner_bikes
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 5                        Honda CB Twister          18000  2010  Individual
# ...                                   ...            ...   ...         ...
# 1055                        Bajaj  ct 100          18000  2017  Individual
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["selling_price"], y=df["km_driven"], alpha=0.5)
plt.xlabel("Selling Price (₹)")
plt.ylabel("Kilometers")
plt.title("Relationship: Selling Price vs. km_driven")
plt.show()

# %%
#Q11>> Identify and remove outliers in the km_driven column using the IQR method.

Q1 = df["km_driven"].quantile(0.25)
Q3 = df["km_driven"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df[(df["km_driven"] >= lower_bound) & (df["km_driven"] <= upper_bound)]

# %%
df_no_outliers
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1054                     Hero  CBZ Xtreme          20000  2010  Individual
# 1055                        Bajaj  ct 100          18000  2017  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
Q1 = df["selling_price"].quantile(0.25)
Q3 = df["selling_price"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df_no_outliers[(df_no_outliers["selling_price"] >= lower_bound) & (df_no_outliers["selling_price"] <= upper_bound)]

# %%
df_no_outliers
# Out:
#                                    name  selling_price  year seller_type  \
# 1                             Honda Dio          45000  2017  Individual
# 3     Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                 Yamaha SZ [2013-2014]          20000  2011  Individual
# 5                      Honda CB Twister          18000  2010  Individual
# 6                  Honda CB Hornet 160R          78500  2018  Individual
# ...                                 ...            ...   ...         ...
# 1054                   Hero  CBZ Xtreme          20000  2010  Individual
# 1055                      Bajaj  ct 100          18000  2017  Individual
# 1057                   Honda CB twister          16000  2012  Individual
# 1058                 Bajaj Discover 125          15000  2013  Individual
# 1059                     Honda CB Shine          12000  2009  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
#Q12>> Perform a bivariate analysis to visualize the relationship between year and selling_price.

plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["year"], y=df["selling_price"], alpha=0.5)
plt.xlabel("Manufacturing Year")
plt.ylabel("Selling Price (₹)")
plt.title("Bivariate Analysis: Year vs. Selling Price")
plt.show()

# %%
#insights>> Scatter plot shows an overall decline in selling price for older bikes.

# %%
#Q13>> What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?

current_year = 2024
df["bike_age"] = current_year - df["year"]

# %%
df.groupby("bike_age")["selling_price"].mean()
# Out:
# bike_age
# 4     183333.333333
# 5     119689.511628
# 6      87603.915385
# 7      78962.121212
# 8      58469.018692
# 9      56500.000000
# 10     48668.131868
# 11     51152.777778
# 12     35976.637681
# 13     35655.721311
# 14     31993.220339
# 15     22240.740741
# 16     34289.285714
# 17     24927.586207
# 18     23380.000000
# 19     16978.571429
# 20     15100.000000
# 21      8000.000000
# 22     20666.666667
# 23     40000.000000
# 24     20833.333333
# 25     15000.000000
# 26     28333.333333
# 27     17500.000000
# 29    150000.000000
# 31    130000.000000
# 33      6000.000000
# 36     20000.000000
# Name: selling_price, dtype: float64

# %%
df.groupby("bike_age")["selling_price"].mean().diff()
# Out:
# bike_age
# 4               NaN
# 5     -63643.821705
# 6     -32085.596243
# 7      -8641.794172
# 8     -20493.102521
# 9      -1969.018692
# 10     -7831.868132
# 11      2484.645910
# 12    -15176.140097
# 13      -320.916370
# 14     -3662.500972
# 15     -9752.479598
# 16     12048.544974
# 17     -9361.699507
# 18     -1547.586207
# 19     -6401.428571
# 20     -1878.571429
# 21     -7100.000000
# 22     12666.666667
# 23     19333.333333
# 24    -19166.666667
# 25     -5833.333333
# 26     13333.333333
# 27    -10833.333333
# 29    132500.000000
# 31    -20000.000000
# 33   -124000.000000
# 36     14000.000000
# Name: selling_price, dtype: float64

# %%
#insights>> 
#5-Year-Old Bikes: -₹63,643 on average.
#6-Year-Old Bikes: -₹32,029 on average.
#7-Year-Old Bikes: -₹8,765 on average.

# %%
#Q14>> Which bike names are priced significantly above the average price for their manufacturing year?

yearly_avg_price = df.groupby("year")["selling_price"].mean()

# %%
df["above_avg"] = df.apply(lambda row: row["selling_price"] > yearly_avg_price[row["year"]], axis=1)

# %%
expensive_bikes = df[df["above_avg"]][["name", "year", "selling_price"]]

# %%
expensive_bikes
# Out:
#                                       name  year  selling_price
# 0                Royal Enfield Classic 350  2019         175000
# 2      Royal Enfield Classic Gunmetal Grey  2018         150000
# 3        Yamaha Fazer FI V 2.0 [2016-2018]  2015          65000
# 7     Royal Enfield Bullet 350 [2007-2011]  2008         180000
# 13                           Yamaha YZF R3  2019         365000
# ...                                    ...   ...            ...
# 1004                  Bajaj Pulsar  NS 200  2016          60000
# 1005                    TVS Apache RTR 160  2014          60000
# 1008                    Bajaj Pulsar 220 F  2012          52000
# 1012                   Bajaj Pulsar NS 200  2014          50000
# 1023                Bajaj Avenger 220 dtsi  2012          45000
#
# [332 rows x 3 columns]

# %%
#Q15> Develop a correlation matrix for numeric columns and visualize it using a heatmap.

plt.figure(figsize=(8, 5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
#insights>> selling_price negatively correlates with bike_age.
#High correlation between selling_price and ex_showroom_price

# %% [markdown]
# # Car Sale Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("Car Sale.csv")
df1
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001    1/2/2022     Geraldine    Male          13500
# 1      C_CND_000002    1/2/2022           Gia    Male        1480000
# 2      C_CND_000003    1/2/2022        Gianna    Male        1035000
# 3      C_CND_000004    1/2/2022       Giselle    Male          13500
# 4      C_CND_000005    1/2/2022         Grace    Male        1465000
# ...             ...         ...           ...     ...            ...
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23905 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
df1.describe()
# Out:
#        Annual Income     Price ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
df1.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    0
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
df1.shape
# Out:
# (23905, 16)

# %%
df1.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Car_id           object
# Date             object
# Customer Name    object
# Gender           object
# Annual Income     int64
# Dealer_Name      object
# Company          object
# Model            object
# Engine           object
# Transmission     object
# Color            object
# Price ($)         int64
# Dealer_No        object
# Body Style       object
# Phone             int64
# Dealer_Region    object
# dtype: object

# %% [markdown]
# # Questions

# %%
#Q1>> What is the average selling price of cars for each dealer, and how does it compare across different dealers?

dealer_avg_price = df1.groupby('Dealer_Name')['Price ($)'].mean().reset_index()
dealer_avg_price
# Out:
#                                         Dealer_Name     Price ($)
# 0               Buddy Storbeck's Diesel Service Inc  27217.261563
# 1                                  C & M Motors Inc  28111.755200
# 2                                       Capitol KIA  28189.703822
# 3                                 Chrysler Plymouth  27555.526400
# 4                            Chrysler of Tri-Cities  28123.091054
# 5                                     Classic Chevy  28602.014446
# 6                           Clay Johnson Auto Sales  27816.027113
# 7                                Diehl Motor CO Inc  27993.929487
# 8                             Enterprise Rent A Car  28312.580800
# 9                        Gartner Buick Hyundai Saab  28247.621019
# 10                              Hatfield Volkswagen  27853.712242
# 11                                  Iceberg Rentals  28522.958533
# 12                     McKinney Dodge Chrysler Jeep  27684.096979
# ...

# %%
dealer_avg_price.columns
# Out:
# Index(['Dealer_Name', 'Price ($)'], dtype='object')

# %%
#Compare Across Different Dealers

dealer_avg_price = dealer_avg_price.sort_values("Price ($)", ascending=False).reset_index()
dealer_avg_price
# Out:
#     index                                      Dealer_Name     Price ($)
# 0      27                                        U-Haul CO  28769.919006
# 1       5                                    Classic Chevy  28602.014446
# 2      19                             Rabun Used Car Sales  28527.536177
# 3      11                                  Iceberg Rentals  28522.958533
# 4       8                            Enterprise Rent A Car  28312.580800
# 5      23                Scrivener Performance Engineering  28297.371589
# 6       9                       Gartner Buick Hyundai Saab  28247.621019
# 7       2                                      Capitol KIA  28189.703822
# 8      22                                 Saab-Belle Dodge  28176.692000
# 9      20                                    Race Car Help  28163.372706
# 10      4                           Chrysler of Tri-Cities  28123.091054
# 11     24                             Star Enterprises Inc  28113.055244
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x="Price ($)", y="Dealer_Name", data=dealer_avg_price, palette="coolwarm")
plt.xlabel("Average Selling Price (₹)")
plt.ylabel("Dealer Name")
plt.title("Comparison of Average Selling Price Across Dealers")
plt.show()

# %%
#insights>> U-Haul CO dealer has the highest average selling price of 28769.919006$.

# %%
df1.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
#Q2>> Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?

car_variation = df1.groupby("Company")["Price ($)"].std().sort_values(ascending = False).head(1)
car_variation
# Out:
# Company
# Lincoln    19658.050211
# Name: Price ($), dtype: float64

# %%
#insight >> A high variation means the brand sells both budget and luxury cars.
#Lincoln brand has the highest variation in prices.

# %%
#Q3>> What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?

sns.boxplot(x = "Transmission", y = "Price ($)", data = df1)
plt.title("Car Price Distribution by Transmission Type")
plt.show()

# %%
#insight >> If manual cars have a higher median price, they are generally more expensive.

# %%
#Q4>> What is the distribution of car prices across different regions?

sns.violinplot(x="Dealer_Region", y="Price ($)", data=df1)
plt.title("Car Price Distribution by Region")
plt.xticks(rotation=45)
plt.show()

# %%
#insights>> Some regions may have higher-priced cars due to demand or taxes.

# %%
#Q5>> What is the distribution of cars based on body styles?

df1.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
df1["Body Style"].value_counts().plot(kind="bar", color="skyblue")
plt.title("Distribution of Cars by Body Style")
plt.xlabel("Body Style")
plt.ylabel("Count")
plt.show()

# %%
#insights>> SUV, Hatchback etc. are more popular body styles

# %%
#Q6>> How does the average selling price of cars vary by customer gender and annual income?

df1.groupby(["Gender", "Annual Income"])["Price ($)"].mean().unstack().plot(kind="bar")
plt.title("Average Selling Price by Gender and Income Bracket")
plt.ylabel("Average Selling Price")
plt.show()

# %%
#insights>> High-income customers may prefer premium cars.

# %%
#Q7>> What is the distribution of car prices by region, and how does the number of cars sold vary by region?

sns.boxplot(x="Dealer_Region", y="Price ($)", data=df1)
plt.title("Car Price Distribution by Region")
plt.xticks(rotation=45)
plt.show()

# %%
df1["Dealer_Region"].value_counts().plot(kind="bar", color="coral")
plt.title("Number of Cars Sold by Region")
plt.xlabel("Region")
plt.ylabel("Count")
plt.show()

# %%
#insights>> Some regions sell more affordable cars

# %%
#Q8>> How does the average car price differ between cars with different engine sizes?

df1.groupby('Engine')['Price ($)'].mean()
# Out:
# Engine
# DoubleÂ Overhead Camshaft    28247.193317
# Overhead Camshaft            27914.710631
# Name: Price ($), dtype: float64

# %%
df1.groupby('Engine')['Price ($)'].mean().plot(kind="line", marker="o")
plt.title("Average Car Price by Engine Size")
plt.xlabel("Engine Size (cc)")
plt.ylabel("Average Price")
plt.show()

# %%
#insights>> Larger engines generally mean higher prices

# %%
df1.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
#Q9>> How do car prices vary based on the customer’s annual income bracket?

sns.boxplot(x="Annual Income", y="Price ($)", data=df1)
plt.title("Car Price Distribution by Customer Income")
plt.xticks(rotation=90)
plt.show()

# %%
#insights>> High-income groups buy expensive cars.

# %%
#Q10>> What are the top 5 car models with the highest number of sales, and how does their price distribution look?

top_models = df1["Model"].value_counts()[:5].index
top_models
# Out:
# Index(['Diamante', 'Silhouette', 'Prizm', 'Passat', 'Jetta'], dtype='object', name='Model')

# %%
sns.boxplot(x ="Model", y ='Price ($)', data = df1[df1['Model'].isin(top_models)])
plt.title("Price Distribution of Top 5 Car Models")
plt.xticks(rotation=45)
plt.show()

# %%
df1.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
#Q11>> How does car price vary with engine size across different car colors, and which colors have the highest price variation?

sns.scatterplot(x="Engine", y="Price ($)", hue="Color", data=df1)
plt.title("Car Price vs. Engine Size by Color")
plt.show()

# %%
#insights>> Some colors may have a premium price.

# %%
df1.dtypes
# Out:
# Car_id           object
# Date             object
# Customer Name    object
# Gender           object
# Annual Income     int64
# Dealer_Name      object
# Company          object
# Model            object
# Engine           object
# Transmission     object
# Color            object
# Price ($)         int64
# Dealer_No        object
# Body Style       object
# Phone             int64
# Dealer_Region    object
# dtype: object

# %%
#Q12>> Is there any seasonal trend in car sales based on the date of sale?

df1["Date"] = pd.to_datetime(df1["Date"])
df1["month"] = df1["Date"].dt.month

# %%
df1['month']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 23901    12
# 23902    12
# 23903    12
# 23904    12
# 23905    12
# Name: month, Length: 23905, dtype: int32

# %%
df1.groupby("month")["Price ($)"].count().plot(kind="line", marker="o")
plt.title("Seasonal Trend in Car Sales")
plt.xlabel("Month")
plt.ylabel("Number of Sales")
plt.show()

# %%
#insights>> Peak sales periods (e.g., festive seasons)

# %%
#Q13>> How does the car price distribution change when considering different combinations of body style and transmission type?

sns.boxplot(x="Body Style", y="Price ($)", hue="Transmission", data=df1)
plt.title("Car Price by Body Style and Transmission")
plt.xticks(rotation=45)
plt.show()

# %%
#insights>> Some combinations have higher prices (e.g., automatic SUVs).

# %%
#Q14>>What is the correlation between car price,engine size, and annual income of customers, and how do these features interact?

'''correlation_matrix = df1[["Price ($)", "Annual Income"]].corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Between Car Price, and Income")
plt.show()'''
# Out:
# 'correlation_matrix = df1[["Price ($)", "Annual Income"]].corr()\nsns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")\nplt.title("Correlation Between Car Price, and Income")\nplt.show()'

# %%
#df1["Engine"] = pd.to_numeric(df1["Engine"], errors="coerce")

# %%
df1.Engine.isnull().sum()
# Out:
# 0

# %%
correlation_matrix = df_cleaned[["Price ($)", "Engine", "Annual Income"]].corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt = '.2f')
plt.title("Correlation Between Car Price, Engine Size, and Income")
plt.show()

# %%
print(df1["Engine"].unique())  # Show first 20 unique values
# Out:
# ['DoubleÂ\xa0Overhead Camshaft' 'Overhead Camshaft']

# %%
print(df1["Engine"].str.contains(r"\d+", regex=True, na=False).sum())
# Out:
# 0

# %%
df1.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'month'],
#       dtype='object')

# %%
df_encoded = pd.get_dummies(df1, columns=["Engine"])

# %%
df_encoded
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001 2022-01-02     Geraldine    Male          13500
# 1      C_CND_000002 2022-01-02           Gia    Male        1480000
# 2      C_CND_000003 2022-01-02        Gianna    Male        1035000
# 3      C_CND_000004 2022-01-02       Giselle    Male          13500
# 4      C_CND_000005 2022-01-02         Grace    Male        1465000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# ...

# %%
correlation_matrix = df_encoded[["Price ($)", "Annual Income"] + list(df_encoded.filter(like="Engine"))].corr()


plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Car Price, Engine Size, and Annual Income")
plt.show()

# %%
#Q15>> How does the average car price vary across different car models and engine types?

df1.groupby(["Model", "Engine"])["Price ($)"].mean().unstack().plot(kind="bar", figsize=(10,5))
plt.title("Average Car Price by Model & Engine Type")
plt.ylabel("Average Price")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Amazon Sales Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df2 = pd.read_csv('amazon.csv')
df2
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df2.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df2.dropna(axis = 0, inplace = True)

# %%
df2.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df2.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
df2.drop('product_id', axis = 1, inplace = True)

# %%
df2.drop('user_id', axis = 1, inplace = True)

# %%
df2.dtypes
# Out:
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
df2['discounted_price']  #must be numerical
# Out:
# 0         ₹399
# 1         ₹199
# 2         ₹199
# 3         ₹329
# 4         ₹154
#          ...
# 1460      ₹379
# 1461    ₹2,280
# 1462    ₹2,219
# 1463    ₹1,399
# 1464    ₹2,863
# Name: discounted_price, Length: 1463, dtype: object

# %%
df2['discounted_price'].unique()
# Out:
# array(['₹399', '₹199', '₹329', '₹154', '₹149', '₹176.63', '₹229', '₹499',
#        '₹299', '₹219', '₹350', '₹159', '₹349', '₹13,999', '₹249',
#        '₹13,490', '₹970', '₹279', '₹59', '₹11,499', '₹14,999', '₹179',
#        '₹389', '₹599', '₹99', '₹899', '₹32,999', '₹209', '₹19,999',
#        '₹999', '₹333', '₹507', '₹309', '₹1,199', '₹799', '₹6,999', '₹230',
#        '₹649', '₹15,999', '₹348', '₹32,990', '₹139', '₹263', '₹7,999',
#        '₹1,599', '₹26,999', '₹115', '₹10,901', '₹1,434', '₹7,299', '₹325',
#        '₹29,999', '₹27,999', '₹30,990', '₹269', '₹24,999', '₹18,990',
#        '₹290', '₹345', '₹1,099', '₹719', '₹849', '₹21,999', '₹449',
#        '₹37,999', '₹7,390', '₹273.10', '₹15,990', '₹210', '₹1,299',
#        '₹347', '₹228', '₹1,499', '₹8,499', '₹20,990', '₹9,999', '₹489',
#        '₹23,999', '₹689', '₹1,699', '₹655', '₹749', '₹195', '₹416',
#        '₹368', '₹29,990', '₹339', '₹15,490', '₹9,490', '₹637', '₹1,089',
# ...

# %%
# Cleaning and converting necessary columns

df2['discounted_price'] = df2['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
df2['discounted_price'].unique()[:20]
# Out:
# array([  399.  ,   199.  ,   329.  ,   154.  ,   149.  ,   176.63,
#          229.  ,   499.  ,   299.  ,   219.  ,   350.  ,   159.  ,
#          349.  , 13999.  ,   249.  , 13490.  ,   970.  ,   279.  ,
#           59.  , 11499.  ])

# %%
df2['discounted_price'].dtypes
# Out:
# dtype('float64')

# %%
df2['actual_price'].unique()
# Out:
# array(['₹1,099', '₹349', '₹1,899', '₹699', '₹399', '₹1,000', '₹499',
#        '₹299', '₹999', '₹339', '₹799', '₹700', '₹899', '₹24,999',
#        '₹21,990', '₹1,799', '₹22,900', '₹199', '₹19,990', '₹19,999',
#        '₹1,999', '₹750', '₹599', '₹666.66', '₹1,900', '₹45,999', '₹695',
#        '₹34,999', '₹1,599', '₹1,208', '₹475', '₹395', '₹2,199', '₹500',
#        '₹2,100', '₹12,999', '₹1,399', '₹21,999', '₹1,499', '₹47,900',
#        '₹845', '₹1,400', '₹14,990', '₹2,999', '₹42,999', '₹30,990',
#        '₹3,999', '₹249', '₹19,125', '₹1,299', '₹39,999', '₹40,990',
#        '₹52,900', '₹800', '₹31,999', '₹1,809', '₹29,999', '₹65,000',
#        '₹20,000', '₹23,990', '₹15,999', '₹44,990', '₹44,999', '₹1,700',
#        '₹595', '₹27,990', '₹1,200', '₹34,990', '₹1,500', '₹49,990',
#        '₹931', '₹2,399', '₹1,339', '₹20,900', '₹15,990', '₹1,600', '₹849',
#        '₹1,199', '₹22,990', '₹2,499', '₹47,990', '₹485', '₹18,990',
# ...

# %%
df2['actual_price'] = df2['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
df2['actual_price'].unique()[:20]
# Out:
# array([ 1099.,   349.,  1899.,   699.,   399.,  1000.,   499.,   299.,
#          999.,   339.,   799.,   700.,   899., 24999., 21990.,  1799.,
#        22900.,   199., 19990., 19999.])

# %%
df2.columns
# Out:
# Index(['product_name', 'category', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'about_product',
#        'user_name', 'review_id', 'review_title', 'review_content', 'img_link',
#        'product_link'],
#       dtype='object')

# %%
df2['rating'].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df2['rating'] = pd.to_numeric(df2['rating'], errors='coerce')

# %%
df2['rating'].unique()
# Out:
# array([4.2, 4. , 3.9, 4.1, 4.3, 4.4, 4.5, 3.7, 3.3, 3.6, 3.4, 3.8, 3.5,
#        4.6, 3.2, 5. , 4.7, 3. , 2.8, 3.1, 4.8, 2.3, nan, 2. , 2.6, 2.9])

# %%
df2['rating_count'].unique()
# Out:
# array(['24,269', '43,994', '7,928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %%
df2['rating_count'] = df2['rating_count'].str.replace(',', '').astype(float)

# %%
df2['rating_count'].dtypes
# Out:
# dtype('float64')

# %%
df2['discount_percentage'].unique()
# Out:
# array(['64%', '43%', '90%', '53%', '61%', '85%', '65%', '23%', '50%',
#        '33%', '55%', '63%', '69%', '60%', '13%', '44%', '38%', '39%',
#        '46%', '41%', '70%', '42%', '72%', '25%', '51%', '73%', '0%',
#        '80%', '28%', '67%', '58%', '35%', '45%', '62%', '54%', '27%',
#        '77%', '56%', '78%', '31%', '86%', '47%', '37%', '75%', '32%',
#        '68%', '66%', '22%', '57%', '17%', '52%', '88%', '20%', '59%',
#        '40%', '26%', '29%', '83%', '71%', '15%', '76%', '48%', '82%',
#        '36%', '89%', '87%', '24%', '34%', '11%', '91%', '7%', '19%',
#        '79%', '21%', '81%', '18%', '49%', '30%', '84%', '10%', '6%',
#        '14%', '74%', '4%', '5%', '16%', '8%', '2%', '94%', '12%', '3%',
#        '9%'], dtype=object)

# %%
df2['discount_percentage'] = df2['discount_percentage'].str.replace('%', '').astype(float)

# %%
df2.dtypes
# Out:
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage    float64
# rating                 float64
# rating_count           float64
# about_product           object
# user_name               object
# review_id               object
# review_title            object
# review_content          object
# img_link                object
# product_link            object
# dtype: object

# %%
df2.isnull().sum()
# Out:
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           0
# about_product          0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df2.dropna(axis = 0, inplace = True)

# %%
df2.isnull().sum()
# Out:
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# # Questions

# %%
#Q1>> What is the average rating for each product category?

df2.groupby('category')['rating'].mean().sort_values(ascending=False)
# Out:
# category
# Computers&Accessories|Tablets                                                                                    4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters                                         4.5
# Electronics|Cameras&Photography|Accessories|Film                                                                 4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                                                     4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                                                               4.5
#                                                                                                                 ...
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                               3.6
# Electronics|HomeTheater,TV&Video|Accessories|3DGlasses                                                           3.5
# ...

# %%
#Q2>> What are the top rating_count products by category?

df2.groupby('category')['rating_count'].idxmax()
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    1157
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                    695
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                            906
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                         748
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                            844
#                                                                                                                           ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens         616
# ...

# %%
top_rating_count_by_category = df2.loc[df2.groupby('category')['rating_count'].idxmax(), ['category', 'product_name', 'rating_count']]
top_rating_count_by_category
# Out:
#                                                category  \
# 1157  Car&Motorbike|CarAccessories|InteriorAccessori...
# 695   Computers&Accessories|Accessories&Peripherals|...
# 906   Computers&Accessories|Accessories&Peripherals|...
# 748   Computers&Accessories|Accessories&Peripherals|...
# 844   Computers&Accessories|Accessories&Peripherals|...
# ...                                                 ...
# 616   OfficeProducts|OfficePaperProducts|Paper|Stati...
# 993   OfficeProducts|OfficePaperProducts|Paper|Stati...
# 765   OfficeProducts|OfficePaperProducts|Paper|Stati...
# 850   OfficeProducts|OfficePaperProducts|Paper|Stati...
# 924   Toys&Games|Arts&Crafts|Drawing&PaintingSupplie...
#
#                                            product_name  rating_count
# 1157  Reffair AX30 [MAX] Portable Air Purifier for C...        1118.0
# 695   rts [2 Pack] Mini USB C Type C Adapter Plug, T...        4426.0
# 906   Hp Wired On Ear Headphones With Mic With 3.5 M...        7222.0
# ...

# %%
top_rating_count_by_category.sort_values(by = 'rating_count', ascending = False).head(10)
# Out:
#                                                category  \
# 12    Electronics|HomeTheater,TV&Video|Accessories|C...
# 352   Electronics|Headphones,Earbuds&Accessories|Hea...
# 370   Electronics|Mobiles&Accessories|Smartphones&Ba...
# 1028  Home&Kitchen|Kitchen&Dining|KitchenTools|Manua...
# 588   Computers&Accessories|ExternalDevices&DataStor...
# 864         Electronics|Accessories|MemoryCards|MicroSD
# 143   Computers&Accessories|NetworkingDevices|Networ...
# 337   Electronics|Mobiles&Accessories|MobileAccessor...
# 191   Computers&Accessories|Accessories&Peripherals|...
# 701   Computers&Accessories|NetworkingDevices|Repeat...
#
#                                            product_name  rating_count
# 12    AmazonBasics Flexible Premium HDMI Cable (Blac...      426973.0
# 352   boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 370   Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      313836.0
# ...

# %%
#Q3>> What is the distribution of discounted prices vs. actual prices?

df2[['discounted_price', 'actual_price']]
# Out:
#       discounted_price  actual_price
# 0                399.0        1099.0
# 1                199.0         349.0
# 2                199.0        1899.0
# 3                329.0         699.0
# 4                154.0         399.0
# ...                ...           ...
# 1460             379.0         919.0
# 1461            2280.0        3045.0
# 1462            2219.0        3080.0
# 1463            1399.0        1890.0
# 1464            2863.0        3690.0
#
# [1462 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df2['discounted_price'], bins=40, color='blue', label='discounted_price', alpha=0.6, kde=True)
sns.histplot(df2['actual_price'], bins=40, color='red', label='actual_price', alpha=0.6, kde=True)
plt.xlabel("Price (₹)")
plt.ylabel("Frequency")
plt.title("Distribution of Discounted vs. Actual Prices")
plt.legend()
plt.show()

# %%
#insights>> A large number of products have low discounted prices.

# %%
#Q4>> How does the average discount percentage vary across categories?

df2.groupby('category')['discount_percentage'].mean().sort_values(ascending=False)
# Out:
# category
# Electronics|Mobiles&Accessories|MobileAccessories|Décor|PhoneCharms                                                 90.0
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors                          90.0
# Electronics|Headphones,Earbuds&Accessories|Earpads                                                                  90.0
# Electronics|Headphones,Earbuds&Accessories|Adapters                                                                 88.0
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MiceAccessories|DustCovers       87.5
#                                                                                                                     ...
# OfficeProducts|OfficeElectronics|Calculators|Basic                                                                   0.0
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SmallApplianceParts&Accessories|StandMixerAccessories     0.0
# ...

# %%
#insights>> some categories have 90%, 87% discount and some have 0% discount.

# %%
#Q5>> What are the most popular product names?

df2[['product_name', 'rating_count']].sort_values(by='rating_count', ascending=False).head(10)
# Out:
#                                           product_name  rating_count
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...      426973.0
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...      426973.0
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...      426973.0
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...      426972.0
# 400  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 352  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...      363711.0
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      313836.0
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...      313836.0
# 473  Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB St...      313832.0

# %%
#Q6>> What are the most popular product keywords?

df2.columns
# Out:
# Index(['product_name', 'category', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'about_product',
#        'user_name', 'review_id', 'review_title', 'review_content', 'img_link',
#        'product_link'],
#       dtype='object')

# %%
from collections import Counter
import re

# %%
# Tokenizing and counting words from product names
all_words = " ".join(df2['product_name']).lower()
words = re.findall(r'\b[a-zA-Z0-9]+\b', all_words)
word_counts = Counter(words)
most_common_keywords = word_counts.most_common(10)

# %%
most_common_keywords
# Out:
# [('with', 750),
#  ('for', 673),
#  ('black', 528),
#  ('usb', 416),
#  ('cable', 412),
#  ('1', 412),
#  ('and', 330),
#  ('c', 285),
#  ('3', 273),
#  ('2', 267)]

# %%
#Q7>> What are the most popular product reviews?

df2['review_title'].value_counts().head(5)
# Out:
# review_title
# Worked on iPhone 7 and didn’t work on XR,Good one,Dull Physical Looks,Just Buy it,Go for it,About the product,Get charging cable at the price,Working well.                                                                                                        10
# Satisfied,Charging is really fast,Value for money,Product review,Good quality,Good product,Good Product,As of now seems good                                                                                                                                        8
# Phone, camera, heating - works for me, may not for all,Good Mobile,Good but not excellent under this budget,Worth the price at 9499,Ok type phone... but unable to make videocall within same service provider.,Phone review,Budget king,Battery backup is good     8
# ...

# %%
#Q8>> What is the correlation between discounted_price and rating?

df2[['discounted_price', 'rating']].corr().iloc[0, 1]
# Out:
# 0.12113187526066165

# %%
correlation = df2[['discounted_price', 'rating']].corr()

# Visualizing the correlation using a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation between Discounted Price and Rating")
plt.show()

# %%
#Q9>> What are the Top 5 categories based on the highest ratings?

top_categories = df2.groupby('category')['rating'].mean().sort_values(ascending=False).head(5)
top_categories
# Out:
# category
# Computers&Accessories|Tablets                                               4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters    4.5
# Electronics|Cameras&Photography|Accessories|Film                            4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                          4.5
# Name: rating, dtype: float64

# %%
#visualization
plt.figure(figsize=(10, 5))
sns.barplot(x=top_categories.index, y=top_categories.values, palette="viridis")
plt.xlabel("Category")
plt.ylabel("Average Rating")
plt.title("Top 5 Categories with Highest Ratings")
plt.xticks(rotation=45)
plt.show()

# %%
#Q10>> Identify any potential areas for improvement or optimization based on the data analysis.

# %% [raw]
# Amazon Product Analysis & Optimization Report

# %% [markdown]
# This report analyzes product pricing, ratings, and customer reviews to identify areas for improvement and optimization. The goal is to enhance product performance, customer satisfaction, and overall sales.

# %% [markdown]
# ### Key Insights from Data Analysis
#
# 1> Pricing Strategy Optimization:-
#
#    No strong correlation between discounted price and rating.
#
# 2> Product Category Focus:-
#
#    Some categories have lower ratings, indicating potential quality issues.
#
# 3> Improving Customer Reviews & Ratings:-
#
#    Reviews are more influenced by quality & experience than price

# %% [markdown]
# ###  Conclusion
#
# 1> Focus on value, not just discounting to drive sales.
#
# 2> Invest in top-rated categories for better growth.
#
# 3> Improve customer experience & engagement.
#
# 4> Use data-driven inventory management to prevent stock issues.

# %% [markdown]
# # Spotify Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df3 = pd.read_csv("spotify.csv")
df3
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %%
df3.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df3.shape
# Out:
# (440, 5)

# %%
df3.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
df3.duplicated().sum()
# Out:
# 27

# %%
# Convert duration from milliseconds to minutes:seconds format
df3["Duration_min"] = (df3["Duration (ms)"] / 60000).round(2)

# %%
df3["Duration_min"]
# Out:
# 0      5.32
# 1      2.90
# 2      4.34
# 3      4.12
# 4      3.64
#        ...
# 433    2.73
# 434    3.13
# 436    3.20
# 437    4.73
# 438    3.67
# Name: Duration_min, Length: 413, dtype: float64

# %% [markdown]
# # Questions

# %%
#Q1> Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful.

df3.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
# there is no null values

# %%
df3.duplicated().sum()
# Out:
# 27

# %%
df3 = df3.drop_duplicates()

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
#Q2>> What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram?

plt.figure(figsize=(8,5))
sns.histplot(df3['Popularity'], bins=20, kde=True, color='blue')
plt.title('Distribution of Track Popularity')
plt.xlabel('Popularity')
plt.ylabel('Count')
plt.show()

# %%
#Q3>> Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot?

df3.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df3['Duration_min'], y=df3['Popularity'], alpha=0.6)
plt.title('Popularity vs. Duration')
plt.xlabel('Duration (minutes)'
plt.ylabel('Popularity')
plt.show()

# %%
#Q4>>Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot

top_artists = df3['Artist'].value_counts().head(10)
top_artists
# Out:
# Artist
# Drake           17
# Eminem          11
# Flo Rida        10
# Ludacris        10
# Timbaland       10
# ¥$              10
# 21 Savage       10
# JAY-Z           10
# Lil Nas X       10
# Travis Scott     9
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.barplot(x=top_artists.index, y=top_artists.values, palette='viridis')
plt.xticks(rotation=45)
plt.title('Top Artists by Track Count')
plt.xlabel('Artist')
plt.ylabel('Number of Tracks')
plt.show()

# %%
#Q5>> What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each?

df3.nsmallest(5, 'Popularity')[['Artist', 'Track Name', 'Popularity']]
# Out:
#              Artist                     Track Name  Popularity
# 207          Pressa  Attachments (feat. Coi Leray)          29
# 231   Justin Bieber                     Intentions          35
# 413  French Montana                Splash Brothers          44
# 225        Lil Baby                  On Me - Remix          47
# 407     Wyclef Jean      911 (feat. Mary J. Blige)          48

# %%
#Q6>> Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display 
#the average popularity for each artist.

top5_artists = df3.groupby('Artist')['Popularity'].mean().nlargest(5)
top5_artists
# Out:
# Artist
# cassö           92.000000
# Trueno          89.000000
# David Guetta    87.000000
# Travis Scott    86.555556
# ¥$              85.100000
# Name: Popularity, dtype: float64

# %%
plt.figure(figsize = (8,6))
sns.barplot(x=top5_artists.index, y=top5_artists.values, palette='viridis')
plt.xticks(rotation=45)
plt.title('Top Artists with highest popularity')
plt.xlabel('Artist')
plt.ylabel('Popularity')
plt.show()

# %%
#Q7>> For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.

df3.nlargest(5, 'Popularity')[['Artist', 'Track Name', 'Popularity']]
# Out:
#            Artist                               Track Name  Popularity
# 40    Jack Harlow                              Lovin On Me          97
# 70      21 Savage                                   redrum          96
# 260            ¥$                                 CARNIVAL          96
# 30   Travis Scott               FE!N (feat. Playboi Carti)          93
# 0           Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92

# %%
#Q8>> Visualize relationships between multiple numerical variables simultaneously using a pair plot.

sns.pairplot(df3[['Popularity', 'Duration_min']], diag_kind='kde')
plt.show()

# %%
#Q9>> Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot 
# or violin plot

# Duration distribution across artists (Box Plot)
plt.figure(figsize=(12,5))
sns.boxplot(x='Artist', y='Duration_min', data=df3[df3['Artist'].isin(top_artists.index)])
plt.xticks(rotation=45)
plt.title('Track Duration Distribution Across Artists')
plt.xlabel('Artist')
plt.ylabel('Duration (minutes)')
plt.show()

# %%
#Q10>> How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a 
# violin plot.

# Popularity distribution per artist (Violin Plot)
plt.figure(figsize=(12,5))
sns.violinplot(x='Artist', y='Popularity', data=df3[df3['Artist'].isin(top_artists.index)])
plt.xticks(rotation=45)
plt.title('Popularity Distribution Across Artists')
plt.xlabel('Artist')
plt.ylabel('Popularity')
plt.show()
